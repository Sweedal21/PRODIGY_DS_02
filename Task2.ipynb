# %% [markdown]
#                                                         DATA SCIENCE

# %% [markdown]
# Task-02:
#
# Perform data cleaning and exploratory data analysis (EDA) on a dataset of your choice, such as the Titanic dataset
# from Kaggle. Explore the relationships between variables and identify patterns and trends in the data.

# %%
#Import Libraries/Dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Load the dataset to oandas dataframe
data=pd.read_csv("C:/Users/Lezan/Documents/Prodigy internship/task2.csv")

# %%
#Displaying the dataframe
data
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    Male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    Male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 884          887         0       2    Male  27.0      0      0  13.0000
# 885          888         1       1  female  19.0      0      0  30.0000
# 886          889         0       3  female  60.0      1      2  23.4500
# 887          890         1       1    Male  26.0      0      0  30.0000
# 888          891         0       3    Male  32.0      0      0   7.7500
#
#      Embarked
# 0           3
# 1           1
# 2           3
# 3           3
# 4           3
# ...

# %%
#Displaying first five data
data.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    Male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    Male  35.0      0      0   8.0500
#
#    Embarked
# 0         3
# 1         1
# 2         3
# 3         3
# 4         3

# %%
#Displaying the last five records
data.tail()
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch   Fare  \
# 884          887         0       2    Male  27.0      0      0  13.00
# 885          888         1       1  female  19.0      0      0  30.00
# 886          889         0       3  female  60.0      1      2  23.45
# 887          890         1       1    Male  26.0      0      0  30.00
# 888          891         0       3    Male  32.0      0      0   7.75
#
#      Embarked
# 884         3
# 885         3
# 886         3
# 887         1
# 888         2

# %%
#Statistical measures
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   889.000000  889.000000  889.000000  889.000000  889.000000
# mean    446.000000    0.382452    2.311586   35.686355    0.524184
# std     256.998173    0.486260    0.834700   17.756733    1.103705
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     224.000000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   32.000000    0.000000
# 75%     668.000000    1.000000    3.000000   54.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare    Embarked
# count  889.000000  889.000000  889.000000
# mean     0.382452   32.096681    2.535433
# std      0.806761   49.697504    0.792088
# min      0.000000    0.000000    1.000000
# 25%      0.000000    7.895800    2.000000
# 50%      0.000000   14.454200    3.000000
# 75%      0.000000   31.000000    3.000000
# ...

# %%
#Rows and columns
data.shape
# Out:
# (889, 9)

# %%
#displaying the columns
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Fare', 'Embarked'],
#       dtype='object')

# %%
#Displaying the datatypes of columns
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Fare           float64
# Embarked         int64
# dtype: object

# %%
#information on total number of rows,columns,data type of each column and memory requirement
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  889 non-null    int64
#  1   Survived     889 non-null    int64
#  2   Pclass       889 non-null    int64
#  3   Sex          889 non-null    object
#  4   Age          889 non-null    float64
#  5   SibSp        889 non-null    int64
#  6   Parch        889 non-null    int64
#  7   Fare         889 non-null    float64
#  8   Embarked     889 non-null    int64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 62.6+ KB

# %%
#Displaying random five record
data.sample(5)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 431          433         1       2  female  42.0      1      0   26.000
# 379          381         1       1  female  42.0      0      0  227.525
# 149          151         0       2    Male  51.0      0      0   12.525
# 184          186         0       1    Male  60.0      0      0   50.000
# 586          588         1       1    Male  60.0      1      1   79.200
#
#      Embarked
# 431         3
# 379         1
# 149         3
# 184         3
# 586         1

# %%
#Displaying the unique values in each columns
print ("Sex : \n",data["Sex"].unique())
print ("Pclass : \n",data["Pclass"].unique())
print ("Parch : \n",data["Parch"].unique())
print ("SibSp : \n",data["SibSp"].unique())
print ("Cabin : \n",data["Age"].unique())
print ("Fare : \n",data["Fare"].unique())
print ("Embarked : \n",data["Embarked"].unique())
print ("Survived : \n",data["Survived"].unique())
# Out:
# Sex :
#  ['Male' 'female']
# Pclass :
#  [3 1 2]
# Parch :
#  [0 1 2 5 3 4 6]
# SibSp :
#  [1 0 3 4 2 5 8]
# Cabin :
#  [22.   38.   26.   35.   60.   54.    2.   27.   14.    4.   58.   20.
#  39.   55.   31.   34.   15.   28.    8.   19.   40.   66.   42.   21.
#  18.    3.    7.   49.   29.   65.   28.5   5.   11.   45.   17.   32.
#  16.   25.    0.83 30.   33.   23.   24.   46.   59.   71.   37.   47.
#  14.5  70.5  32.5  12.    9.   36.5  51.   55.5  40.5  44.    1.   61.
#  56.   50.   36.   45.5  20.5  62.   41.   52.   63.   23.5   0.92 43.
#  10.   64.   13.   48.    0.75 53.   57.   80.   70.   24.5   6.    0.67
#  30.5   0.42 34.5  74.  ]
# Fare :
#  [  7.25    71.2833   7.925   53.1      8.05     8.4583  51.8625  21.075
#   11.1333  30.0708  16.7     26.55    31.275    7.8542  16.      29.125
#   13.      18.       7.225   26.       8.0292  35.5     31.3875 263.
#    7.8792   7.8958  27.7208 146.5208   7.75    10.5     82.1708  52.
# ...

# %%
#Checking if there are any missing values
print(data.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
# identify datatypes of the 11 columns, add the stats to the datadict
datadict = pd.DataFrame(data.dtypes)
datadict
# Out:
#                    0
# PassengerId    int64
# Survived       int64
# Pclass         int64
# Sex           object
# Age          float64
# SibSp          int64
# Parch          int64
# Fare         float64
# Embarked       int64

# %%
# identify missing values of the 11 columns,add the stats to the datadict
datadict['MissingVal'] = data.isnull().sum()
datadict
# Out:
#                    0  MissingVal
# PassengerId    int64           0
# Survived       int64           0
# Pclass         int64           0
# Sex           object           0
# Age          float64           0
# SibSp          int64           0
# Parch          int64           0
# Fare         float64           0
# Embarked       int64           0

# %%
# Identify number of unique values, For object nunique will the number of levels
# Add the stats the data dict
datadict['NUnique']=data.nunique()
datadict
# Out:
#                    0  MissingVal  NUnique
# PassengerId    int64           0      889
# Survived       int64           0        2
# Pclass         int64           0        3
# Sex           object           0        2
# Age          float64           0       88
# SibSp          int64           0        7
# Parch          int64           0        7
# Fare         float64           0      247
# Embarked       int64           0        3

# %%
# Identify the count for each variable, add the stats to datadict
datadict['Count']=data.count()
datadict
# Out:
#                    0  MissingVal  NUnique  Count
# PassengerId    int64           0      889    889
# Survived       int64           0        2    889
# Pclass         int64           0        3    889
# Sex           object           0        2    889
# Age          float64           0       88    889
# SibSp          int64           0        7    889
# Parch          int64           0        7    889
# Fare         float64           0      247    889
# Embarked       int64           0        3    889

# %%
# rename the 0 column
datadict = datadict.rename(columns={0:'DataType'})
datadict
# Out:
#             DataType  MissingVal  NUnique  Count
# PassengerId    int64           0      889    889
# Survived       int64           0        2    889
# Pclass         int64           0        3    889
# Sex           object           0        2    889
# Age          float64           0       88    889
# SibSp          int64           0        7    889
# Parch          int64           0        7    889
# Fare         float64           0      247    889
# Embarked       int64           0        3    889

# %%
#Countplot to diplay survival based on sex
sns.countplot(x='Sex', hue='Survived', data=data)
plt.show()

# %% [markdown]
# Inference:Women had a significantly higher survival rate than men.

# %%
# Analyze passenger survival by Pclass (Passenger Class)
sns.displot(data[data['Survived']==1]['Pclass'], label='Survived')

plt.legend()
plt.show()

# %%
# Analyze passenger deceased by Pclass (Passenger Class)
sns.displot(data[data['Survived']==0]['Pclass'], label='Deceased')
plt.legend()
plt.show()

# %% [markdown]
# Inference:First-class passengers had a higher survival rate

# %%
#Finding the number of passengers survived and deceased
titanic_survived = data[data["Survived"]==1]
titanic_non_survived = data[data["Survived"]==0]
print(data.groupby("Survived")["PassengerId"].count())
# Out:
# Survived
# 0    549
# 1    340
# Name: PassengerId, dtype: int64

# %%
#Finding the percentage of passengers survived and deceased
data.Survived.value_counts(normalize=True)
# Out:
# 0    0.617548
# 1    0.382452
# Name: Survived, dtype: float64

# %% [markdown]
# Inference:only 38% of the passengers were survived, where as a majority 61% the passenger did not survive.

# %% [markdown]
# Plots:

# %%
fig=plt.figure(figsize=(5, 5))
sns.countplot(x='Survived',data=data)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# Inference:Majority of the passengers did not survive

# %%
fig=plt.figure(figsize=(5, 5))
sns.countplot(x='Pclass',data=data)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %% [markdown]
# Inference:The majority of passengers paid lower fares, aligning with a larger number of third-class tickets.

# %%
fig=plt.figure(figsize=(5, 5))
sns.countplot(x='Sex',data=data)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %% [markdown]
# Inference:There were larger than number of male

# %%
fig=plt.figure(figsize=(5, 5))
sns.countplot(x='SibSp',data=data)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %% [markdown]
# Inference:There were more number of people travelling alone

# %%
fig=plt.figure(figsize=(5, 5))
sns.countplot(x='Parch',data=data)
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %% [markdown]
# Inference:There were more number of people who were travelling alone

# %%
fig=plt.figure(figsize=(5, 5))
sns.countplot(x='Embarked',data=data)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# Inference:There we highest number of passenger who boarded from the third port i.e.,Southempton

# %%
sns.catplot(x='Fare',kind='box',data=data)

# %%
sns.displot(data['Fare'], kde=True)

# %% [markdown]
# Inference:The maximum number of people have brought a low faired ticket.The data is positively skewed

# %%
sns.catplot(x='Age',kind='box',data=data)

# %%
sns.displot(data['Age'],kde=True)

# %% [markdown]
# Inference:The age is bimodal i.e., It has two clear peaks.Majority of the people are in the age group between 50-60 and second highest people are between the gae group 20-30

# %%
#the distribution of ages of the passengers
plt.figure(figsize=(10, 6))
sns.histplot(data=data, x='Age', kde=True, hue='Sex')
plt.title('Age Distribution by Gender')
plt.show()

# %% [markdown]
# Inference:The highest number of male and female are between the age group 20-35

# %%
#survival rates based on passenger class.
plt.figure(figsize=(10, 6))
sns.barplot(data=data, x='Pclass', y='Survived', hue='Sex')
plt.title('Survival Rate by Passenger Class and Gender')
plt.show()

# %% [markdown]
# Inference:Females from all the passenger classes has highest survival rate.Majority of the male have been deceased.

# %%
#survival rates based on embarkation port.
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Embarked', hue='Survived')
plt.title('Survival Count based on Embarkation Port')
plt.show()

# %% [markdown]
# Inference:Majority of the people who have deceased are from Sothempton

# %%
#Let's analyze survival based on fare and class.
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='Pclass', y='Fare', hue='Survived')
plt.ylim(0, 300)  # Limiting y-axis to 300 for better visualization
plt.title('Fare distribution by Passenger Class and Survival')
plt.show()

# %% [markdown]
# Inference:Highest number of people have survived from first class and least from third class

# %%
#The survival count based on the family size
#Creating a new column 'FamilySize' by adding 'sibsp' & 'parch'
data['family_size'] = data['SibSp'] + data['Parch']
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='family_size', hue='Survived')
plt.title('Survival Count based on Family Size')
plt.show()

# %% [markdown]
# Inference:Passengers traveling alone or with one parent/child had higher survival rates compared to larger families.

# %%
#analyze survival rates by the number of siblings/spouses aboard.
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='SibSp', hue='Survived')
plt.title('Survival Count based on Number of Siblings/Spouses Aboard')
plt.show()

# %% [markdown]
# Inference:Solo travelers and those with a small family size (1-3 members) had better survival outcomes than larger families.

# %%
#Histogram to represent distriution of all the columns
data.hist(figsize=(10,10))
plt.show()

# %%
#Converting categorical data to numberical data
data['Sex']=data['Sex'].map({'Male':0,'Female':1})

# %%
#Correlation matrix
correlation=data.corr()

# %%
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True)
# Out:
# <Axes: >

# %%
#pairplot representaion of all columns
sns.pairplot(data)

# %% [markdown]
# Analysis result:
#
# *Women had a significantly higher survival rate than men.
#
# *First-class passengers had a higher survival rate.
#
# *The majority of passengers had third-class tickets.
#
# *Those with one sibling or spouse onboard seemed to have a slightly better survival rate than those alone or with many siblings/spouses.
#
# *Passengers traveling alone or with one parent/child had higher survival rates compared to larger families.
#
# *Younger passengers (children) had a better survival rate, while the elderly had lower survival chances.
